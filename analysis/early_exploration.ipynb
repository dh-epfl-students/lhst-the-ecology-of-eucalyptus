# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/document_data_clean.csv")

# %%
plt.hist(df["date_clean"])
# Out:
# (array([1.8000e+01, 6.3000e+01, 9.4000e+01, 1.5700e+02, 2.3000e+02,
#         1.7070e+03, 1.1675e+04, 2.1576e+04, 2.0847e+04, 1.7580e+03]),
#  array([1785. , 1799.8, 1814.6, 1829.4, 1844.2, 1859. , 1873.8, 1888.6,
#         1903.4, 1918.2, 1933. ]),
#  <BarContainer object of 10 artists>)

# %%
df["publisher_place_clean"]
# Out:
# 0             Paris
# 1             Paris
# 2             Paris
# 3             Paris
# 4             Paris
#             ...
# 58151         Paris
# 58152         Alger
# 58153         Paris
# 58154    Tananarive
# 58155          Oran
# Name: publisher_place_clean, Length: 58156, dtype: str

# %%
df.groupby(by="publisher_place_clean").size().sort_values(ascending=False)[:20]
# Out:
# publisher_place_clean
# Paris             28117
# Alger              7100
# Lyon               1525
# Marseille          1332
# Toulouse            979
# Oran                889
# Bordeaux            669
# Pau                 662
# Dijon               662
# Tananarive          549
# Tours               523
# Montpellier         465
# Cusset              342
# Lille               342
# Besançon            341
# Saint-Denis         339
# Constantinople      332
# Bastia              311
# Bourges             298
# Alexandrie          272
# dtype: int64

# %%
df.groupby(by="author_name_clean").size().sort_values(ascending=False)[:20]
# Out:
# author_name_clean
# Madagascar                                                                     519
# Syndicat des entrepreneurs de travaux publics de l'Algérie et de la Tunisie    409
# Algérie (Période coloniale)                                                    334
# Union républicaine (France)                                                    212
# Pharmacie centrale de France et Maison de droguerie Menier réunies (Paris)     203
# Parti social français                                                          151
# Agence V Fouchier                                                              150
# Fédération algérienne du commerce et de l'industrie                            150
# France                                                                         143
# Tattersall français                                                            108
# Appel au peuple (France)                                                       102
# Groupe Bayard                                                                  101
# Réveillaud, Eugène                                                              84
# Union conservatrice du Gers                                                     82
# Bourse de Paris                                                                 77
# Réunion                                                                         70
# Société nationale de protection de la nature (France)                           69
# Société médicale des hôpitaux de Lyon                                           69
# Chambre nationale des propriétaires (France)                                    68
# Parti communiste français                                                       68
# dtype: int64

# %%
df.groupby(by="publisher_name_clean").size().sort_values(ascending=False)[:20]
# Out:
# publisher_name_clean
# [s.n.]                           41032
# [s.n]                             1281
# Le Progrès                        1190
# [s.n.?]                            885
# [s. n.]                            582
# Imprimerie nationale               495
# Hachette                           355
# Figaro                             295
# au bureau du journal               293
# Bureaux                            233
# Le Voltaire                        218
# Pharmacie centrale de France       203
# Masson                             196
# Rueff                              187
# Le Petit Parisien                  174
# Journaux officiels                 168
# Jean-Baptiste-Claude Souchois      166
# J.-B. Baillière et fils            165
# Librairie illustrée                155
# Bureau du journal                  150
# dtype: int64
